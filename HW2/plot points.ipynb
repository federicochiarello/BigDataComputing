# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
test_data = pd.read_csv(r".\dataset\testdataHW2.txt", header=None)

plt.figure(figsize=(12,8))
plt.scatter(test_data[0], test_data[1])
plt.show()

# %%
uber_data = pd.read_csv(r".\dataset\uber-small.csv", header=None)

plt.figure(figsize=(12,8))
plt.scatter(uber_data[0], uber_data[1])
plt.show()

# %%
big_data = pd.read_csv(r".\dataset\artificial9000.txt", header=None)

plt.figure(figsize=(12,8))
plt.scatter(big_data[0], big_data[1])
plt.show()

# %%
big_data.info
# Out:
# <bound method DataFrame.info of            0       1
# 0    -30.190  -1.676
# 1    -51.694 -38.031
# 2    -47.641 -60.492
# 3    -15.099 -42.865
# 4    -25.474 -34.308
# ...      ...     ...
# 9195 -21.195 -24.780
# 9196  -8.771  15.981
# 9197  16.745 -46.579
# 9198   7.217 -14.146
# 9199  16.617  16.423
#
# [9200 rows x 2 columns]>
